# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Hello, Jagdish!

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
number = int(input("Enter a number: "))
if number > 0:
    print("Positive")
elif number < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    largest = a 
elif b >= a and b >= c:
    largest = b
else:
    largest = c
print(f"The largest number is: {largest}")

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
number = int(input("Enter a number: "))
if number <=0:
    print("Factorial is not defined for negative numbers or zero")
elif number == 1:
    print(f"The Factorial is 1")
else:
    factorial = 1
    for i in range(2, number+1):
        factorial *=i
    print(f"The Factorial is {factorial}")
# Out:
# The Factorial is 1

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
data_type_num = 10
data_type_float = 10.5
data_type_str = "Hello"
data_type_bool = True

print(f"Integer: {data_type_num}, Type: {type(data_type_num)}")
print(f"Float: {data_type_float}, Type: {type(data_type_float)}")   
print(f"String: {data_type_str}, Type: {type(data_type_str)}")
print(f"Boolean: {data_type_bool}, Type: {type(data_type_bool)}")
# Out:
# Integer: 10, Type: <class 'int'>
# Float: 10.5, Type: <class 'float'>
# String: Hello, Type: <class 'str'>
# Boolean: True, Type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
a, b = b,a
print(f"after swapping: a = {a}, b = {b}")
# Out:
# after swapping: a = 2, b = 5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
#following code is to demonstrate temperature conversion from celcius to fahrenheit and vice versa
Temperature = input("Enter the temperature you want to onvert (e.g., 45c or 102f): ")
if Temperature[-1] in ['c','C']:
    celsius  = float(Temperature[:-1])
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius}°C is equal to {fahrenheit}°F")
elif Temperature[-1] in ['f','F']:
    fahrenheit = float(Temperature[:-1])
    celsius = (fahrenheit - 32) * 5/9
    print(f"{fahrenheit}°F is equal to {celsius}°C")
else:
    print("Invalid input format. Please enter the temperature followed by 'c' or 'f'.")
# Out:
# 10.0°C is equal to 50.0°F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
f_name = input("Enter your first name: ")
l_name = input("Enter your last name: ")
print(f"Hello {l_name} {f_name}")

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
